# %%
#dbutils.fs.unmount("/mnt/test-projects")

#dbutils.fs.mount(
#  source = "wasbs://test-projects@ardsteamstorage1.blob.core.windows.net",
#  mount_point = "/mnt/test-projects",
#  extra_configs = {"fs.azure.account.key.ardsteamstorage1.blob.core.windows.net":"2Gacmofk/DpJgWzJ8rou/HQ0Ws6AD+CqWdQLB4Qbz3n5CIYW22d378cObhtIfPHKaYCQcc1bLGPOn/dDAPLNWg=="})
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">/mnt/test-projects has been unmounted.
# Out[1]: True</div>

# %% [markdown]
# # BERT Project: Sentiment Analysis with Deep Learning using BERT
#
# ## Task: Data Storage check and exploratory data analysis
#
# Here I am using the SMILE twitter dataset.

# %%
import torch
import pandas as pd
from tqdm.notebook import tqdm
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
# %python
df = pd.read_csv('/dbfs/mnt/test-projects/BERT project/Data/smile-annotations-final.csv', names=['id', 'text', 'category'])
df.set_index('id', inplace =True)
df.head()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[46]: </div>
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>text</th>
#       <th>category</th>
#     </tr>
#     <tr>
#       <th>id</th>
#       <th></th>
#       <th></th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>611857364396965889</th>
#       <td>@aandraous @britishmuseum @AndrewsAntonio Merc...</td>
#       <td>nocode</td>
#     </tr>
#     <tr>
#       <th>614484565059596288</th>
#       <td>Dorian Gray with Rainbow Scarf #LoveWins (from...</td>
#       <td>happy</td>
#     </tr>
#     <tr>
#       <th>614746522043973632</th>
#       <td>@SelectShowcase @Tate_StIves ... Replace with ...</td>
#       <td>happy</td>
#     </tr>
#     <tr>
#       <th>614877582664835073</th>
#       <td>@Sofabsports thank you for following me back. ...</td>
#       <td>happy</td>
#     </tr>
#     <tr>
#       <th>611932373039644672</th>
#       <td>@britishmuseum @TudorHistory What a beautiful ...</td>
#       <td>happy</td>
#     </tr>
#   </tbody>
# </table>
# </div>

# %%
df.text.iloc[0]
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[47]: &#39;@aandraous @britishmuseum @AndrewsAntonio Merci pour le partage! @openwinemap&#39;</div>

# %% [markdown]
# How many categories are there?

# %%
df.category.value_counts()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[48]: nocode               1572
# happy                1137
# not-relevant          214
# angry                  57
# surprise               35
# sad                    32
# happy|surprise         11
# happy|sad               9
# disgust|angry           7
# disgust                 6
# sad|angry               2
# sad|disgust             2
# sad|disgust|angry       1
# Name: category, dtype: int64</div>

# %%
df = df[~df.category.str.contains('\|')]
df.category.value_counts()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[49]: nocode          1572
# happy           1137
# not-relevant     214
# angry             57
# surprise          35
# sad               32
# disgust            6
# Name: category, dtype: int64</div>

# %%
df = df[df.category != 'nocode' ]
df.category.value_counts()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[50]: happy           1137
# not-relevant     214
# angry             57
# surprise          35
# sad               32
# disgust            6
# Name: category, dtype: int64</div>

# %%
label_dict = {}
for i,j in enumerate(df.category.value_counts().index):
  label_dict[j] = i
  
label_dict
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[51]: {&#39;happy&#39;: 0,
#  &#39;not-relevant&#39;: 1,
#  &#39;angry&#39;: 2,
#  &#39;surprise&#39;: 3,
#  &#39;sad&#39;: 4,
#  &#39;disgust&#39;: 5}</div>

# %%
df['label'] = df.category.replace(label_dict)
df.head()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[52]: </div>
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>text</th>
#       <th>category</th>
#       <th>label</th>
#     </tr>
#     <tr>
#       <th>id</th>
#       <th></th>
#       <th></th>
#       <th></th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>614484565059596288</th>
#       <td>Dorian Gray with Rainbow Scarf #LoveWins (from...</td>
#       <td>happy</td>
#       <td>0</td>
#     </tr>
#     <tr>
#       <th>614746522043973632</th>
#       <td>@SelectShowcase @Tate_StIves ... Replace with ...</td>
#       <td>happy</td>
#       <td>0</td>
#     </tr>
#     <tr>
#       <th>614877582664835073</th>
#       <td>@Sofabsports thank you for following me back. ...</td>
#       <td>happy</td>
#       <td>0</td>
#     </tr>
#     <tr>
#       <th>611932373039644672</th>
#       <td>@britishmuseum @TudorHistory What a beautiful ...</td>
#       <td>happy</td>
#       <td>0</td>
#     </tr>
#     <tr>
#       <th>611570404268883969</th>
#       <td>@NationalGallery @ThePoldarkian I have always ...</td>
#       <td>happy</td>
#       <td>0</td>
#     </tr>
#   </tbody>
# </table>
# </div>

# %%
df['data_type'] = 'not_set'
df.head()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[53]: </div>
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>text</th>
#       <th>category</th>
#       <th>label</th>
#       <th>data_type</th>
#     </tr>
#     <tr>
#       <th>id</th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>614484565059596288</th>
#       <td>Dorian Gray with Rainbow Scarf #LoveWins (from...</td>
#       <td>happy</td>
#       <td>0</td>
#       <td>not_set</td>
#     </tr>
#     <tr>
#       <th>614746522043973632</th>
#       <td>@SelectShowcase @Tate_StIves ... Replace with ...</td>
#       <td>happy</td>
#       <td>0</td>
#       <td>not_set</td>
#     </tr>
#     <tr>
#       <th>614877582664835073</th>
#       <td>@Sofabsports thank you for following me back. ...</td>
#       <td>happy</td>
#       <td>0</td>
#       <td>not_set</td>
#     </tr>
#     <tr>
#       <th>611932373039644672</th>
#       <td>@britishmuseum @TudorHistory What a beautiful ...</td>
#       <td>happy</td>
#       <td>0</td>
#       <td>not_set</td>
#     </tr>
#     <tr>
#       <th>611570404268883969</th>
#       <td>@NationalGallery @ThePoldarkian I have always ...</td>
#       <td>happy</td>
#       <td>0</td>
#       <td>not_set</td>
#     </tr>
#   </tbody>
# </table>
# </div>

# %% [markdown]
# ## Training and test/validation data split

# %%
from sklearn.model_selection import train_test_split
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
X_train, X_test, y_train, y_test = train_test_split(
  df.index.values, df.label.values, 
  test_size = 0.15, random_state = 17, stratify = df.label.values
)

print(X_train.shape)
print(y_train.shape)
print(X_test.shape)
print(y_test.shape)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">(1258,)
# (1258,)
# (223,)
# (223,)
# </div>

# %%
df.loc[X_train,'data_type'] = 'train'
df.loc[X_test,'data_type' ]= 'val'
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
df.groupby(['category', 'label', 'data_type']).count()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[69]: </div>
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th></th>
#       <th></th>
#       <th>text</th>
#     </tr>
#     <tr>
#       <th>category</th>
#       <th>label</th>
#       <th>data_type</th>
#       <th></th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th rowspan="2" valign="top">angry</th>
#       <th rowspan="2" valign="top">2</th>
#       <th>train</th>
#       <td>48</td>
#     </tr>
#     <tr>
#       <th>val</th>
#       <td>9</td>
#     </tr>
#     <tr>
#       <th rowspan="2" valign="top">disgust</th>
#       <th rowspan="2" valign="top">5</th>
#       <th>train</th>
#       <td>5</td>
#     </tr>
#     <tr>
#       <th>val</th>
#       <td>1</td>
#     </tr>
#     <tr>
#       <th rowspan="2" valign="top">happy</th>
#       <th rowspan="2" valign="top">0</th>
#       <th>train</th>
#       <td>966</td>
#     </tr>
#     <tr>
#       <th>val</th>
#       <td>171</td>
#     </tr>
#     <tr>
#       <th rowspan="2" valign="top">not-relevant</th>
#       <th rowspan="2" valign="top">1</th>
#       <th>train</th>
#       <td>182</td>
#     </tr>
#     <tr>
#       <th>val</th>
#       <td>32</td>
#     </tr>
#     <tr>
#       <th rowspan="2" valign="top">sad</th>
#       <th rowspan="2" valign="top">4</th>
#       <th>train</th>
#       <td>27</td>
#     </tr>
#     <tr>
#       <th>val</th>
#       <td>5</td>
#     </tr>
#     <tr>
#       <th rowspan="2" valign="top">surprise</th>
#       <th rowspan="2" valign="top">3</th>
#       <th>train</th>
#       <td>30</td>
#     </tr>
#     <tr>
#       <th>val</th>
#       <td>5</td>
#     </tr>
#   </tbody>
# </table>
# </div>

# %% [markdown]
# ## Loading Tokenizier and Encoding our Data

# %%
#!pip install transformers
from transformers import BertTokenizer
from torch.utils.data import TensorDataset
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
tokenizer = BertTokenizer.from_pretrained(
  'bert-base-uncased', do_lower_case = True
)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# Downloading: 100%|██████████| 232k/232k [00:00&lt;00:00, 12.9MB/s]
# Downloading: 100%|██████████| 28.0/28.0 [00:00&lt;00:00, 34.6kB/s]
# Downloading: 100%|██████████| 466k/466k [00:00&lt;00:00, 16.6MB/s]
# </div>

# %%
encoded_data_train = tokenizer.batch_encode_plus(
  df[df.data_type == 'train'].text.values,
  add_special_tokens = True, return_attention_mask= True,
  pad_to_max_length = True, max_length = 256, return_tensors = 'pt'
)

encoded_data_val = tokenizer.batch_encode_plus(
  df[df.data_type == 'val'].text.values,
  add_special_tokens = True, return_attention_mask= True,
  pad_to_max_length = True, max_length = 256, return_tensors = 'pt'
)

input_ids_train = encoded_data_train['input_ids']
attention_masks_train = encoded_data_train['attention_mask']
labels_train = torch.tensor(df[df.data_type=='train'].label.values)

input_ids_val = encoded_data_val['input_ids']
attention_masks_val = encoded_data_val['attention_mask']
labels_val = torch.tensor(df[df.data_type=='val'].label.values)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
print(type(input_ids_train),' as input ids with size ' ,input_ids_train.shape)
print(type(attention_masks_train),' as attention_masks_train with size ' ,attention_masks_train.shape)
print(type(labels_val),' as labels_val with size ' ,labels_val.shape)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">&lt;class &#39;torch.Tensor&#39;&gt;  as input ids with size  torch.Size([1258, 256])
# &lt;class &#39;torch.Tensor&#39;&gt;  as attention_masks_train with size  torch.Size([1258, 256])
# &lt;class &#39;torch.Tensor&#39;&gt;  as labels_val with size  torch.Size([223])
# </div>

# %%
dataset_train = TensorDataset(input_ids_train, attention_masks_train, labels_train)

dataset_val = TensorDataset(input_ids_val, attention_masks_val, labels_val)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
print(type(dataset_train),' as dataset_train with size ', len(dataset_train))
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">&lt;class &#39;torch.utils.data.dataset.TensorDataset&#39;&gt;  as dataset_train with size  1258
# </div>

# %% [markdown]
# ## Task 5: Setting up BERT pretrained model

# %%
from transformers import BertForSequenceClassification
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
model = BertForSequenceClassification.from_pretrained(
  'bert-base-uncased', num_labels = len(label_dict),
  output_attentions = False, output_hidden_states= False
                                     )
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Some weights of the model checkpoint at bert-base-uncased were not used when initializing BertForSequenceClassification: [&#39;cls.predictions.transform.dense.bias&#39;, &#39;cls.seq_relationship.bias&#39;, &#39;cls.predictions.transform.LayerNorm.weight&#39;, &#39;cls.predictions.decoder.weight&#39;, &#39;cls.predictions.transform.dense.weight&#39;, &#39;cls.seq_relationship.weight&#39;, &#39;cls.predictions.transform.LayerNorm.bias&#39;, &#39;cls.predictions.bias&#39;]
# - This IS expected if you are initializing BertForSequenceClassification from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing BertForSequenceClassification from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# Some weights of BertForSequenceClassification were not initialized from the model checkpoint at bert-base-uncased and are newly initialized: [&#39;classifier.bias&#39;, &#39;classifier.weight&#39;]
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# </div>

# %% [markdown]
# ## Creating Data Loaders

# %%
from torch.utils.data import DataLoader, RandomSampler, SequentialSampler
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
batch_size = 32 #lower if the machine is weak

dataloader_train = DataLoader(dataset_train,
                             sampler = RandomSampler(dataset_train), batch_size = batch_size
                             )

dataloader_val = DataLoader(dataset_val,
                             sampler = RandomSampler(dataset_val), batch_size = batch_size
                             )
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %% [markdown]
# ## Setting up Optimizer and Scheduler

# %%
from transformers import AdamW, get_linear_schedule_with_warmup
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
optimizer = AdamW( model.parameters(),
                 lr = 1e-5, eps = 1e-8
                 )
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
epochs = 10

scheduler = get_linear_schedule_with_warmup(
  optimizer, num_warmup_steps=0,
  num_training_steps=len(dataloader_train)*epochs
)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %% [markdown]
# ## Performence Metrics

# %%
import numpy as np
from sklearn.metrics import f1_score
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
def f1_score_func( preds, lables):
  preds_flat = np.argmax(preds, axis=1).flatten()
  lables_flat = lables.flatten()
  return f1_score(labels_flat, preds_flat, average= 'weighted')
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
def accuracy_per_class(preds, labels):
  label_dict_inverse = {v, k for k, v in label_dict.items()}
