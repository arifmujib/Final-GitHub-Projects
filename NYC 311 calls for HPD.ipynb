# %% [markdown]
# ## I need to answer several questions. The answers to those questions must be supported by data and analytics. These are the questions:
#
# ### 1. Which type of complaint should the Department of Housing Preservation and Development of New York City focus on first?
# ### 2. Should the Department of Housing Preservation and Development of New York City focus on any particular set of boroughs, ZIP codes, or street (where the complaints are severe) for the specific type of complaints you identified in response to Question 1?
# ### 3. Does the Complaint Type that you identified in response to question 1 have an obvious relationship with any particular characteristic or characteristics of the houses or buildings?
# ### 4. Can a predictive model be built for a future prediction of the possibility of complaints of the type that you have identified in response to question 1?

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df= pd.read_csv('/kaggle/input/nyc-311-hpd-calls/311_Service_Requests_from_2010_to_Present.csv')
print(df.shape)
df.head()
# Out:
# /opt/conda/lib/python3.6/site-packages/IPython/core/interactiveshell.py:3063: DtypeWarning: Columns (11,12,13,14,17,20) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)
# (6087779, 41)
#    Unique Key            Created Date             Closed Date Agency  \
# 0    45980284  04/10/2020 09:10:10 AM                     NaN    HPD
# 1    45978285  04/10/2020 12:13:02 PM                     NaN    HPD
# 2    45978263  04/10/2020 07:37:51 AM  04/10/2020 05:56:21 PM    HPD
# 3    45976274  04/10/2020 01:53:42 PM                     NaN    HPD
# 4    45980927  04/10/2020 11:20:50 AM                     NaN    HPD
#
#                                          Agency Name        Complaint Type  \
# 0  Department of Housing Preservation and Develop...        HEAT/HOT WATER
# 1  Department of Housing Preservation and Develop...        HEAT/HOT WATER
# 2  Department of Housing Preservation and Develop...        HEAT/HOT WATER
# 3  Department of Housing Preservation and Develop...  UNSANITARY CONDITION
# 4  Department of Housing Preservation and Develop...        HEAT/HOT WATER
#
#         Descriptor         Location Type  Incident Zip  \
# 0  ENTIRE BUILDING  RESIDENTIAL BUILDING       10030.0
# 1  ENTIRE BUILDING  RESIDENTIAL BUILDING       11235.0
# 2  ENTIRE BUILDING  RESIDENTIAL BUILDING       10462.0
# 3            PESTS  RESIDENTIAL BUILDING       10462.0
# 4  ENTIRE BUILDING  RESIDENTIAL BUILDING       10458.0
#
#             Incident Address  ... Vehicle Type Taxi Company Borough  \
# 0       138 WEST  137 STREET  ...          NaN                  NaN
# 1  3105 BRIGHTON    3 STREET  ...          NaN                  NaN
# 2      2040 BRONXDALE AVENUE  ...          NaN                  NaN
# 3          1435 DORIS STREET  ...          NaN                  NaN
# 4     2410 WASHINGTON AVENUE  ...          NaN                  NaN
#
#   Taxi Pick Up Location Bridge Highway Name Bridge Highway Direction  \
# 0                   NaN                 NaN                      NaN
# 1                   NaN                 NaN                      NaN
# 2                   NaN                 NaN                      NaN
# 3                   NaN                 NaN                      NaN
# 4                   NaN                 NaN                      NaN
#
#   Road Ramp Bridge Highway Segment   Latitude  Longitude  \
# 0       NaN                    NaN  40.815900 -73.941112
# 1       NaN                    NaN  40.576327 -73.964056
# 2       NaN                    NaN  40.850795 -73.866537
# 3       NaN                    NaN  40.835502 -73.849272
# 4       NaN                    NaN  40.858053 -73.890913
#
#                                    Location
# 0    (40.81590010208267, -73.9411124524788)
# 1   (40.576327154021826, -73.9640562531078)
# 2  (40.850794587937656, -73.86653703997725)
# 3  (40.835501747393344, -73.84927206222912)
# 4   (40.858052508996636, -73.8909130551251)
#
# [5 rows x 41 columns]

# %%
df.columns
# Out:
# Index(['Unique Key', 'Created Date', 'Closed Date', 'Agency', 'Agency Name',
#        'Complaint Type', 'Descriptor', 'Location Type', 'Incident Zip',
#        'Incident Address', 'Street Name', 'Cross Street 1', 'Cross Street 2',
#        'Intersection Street 1', 'Intersection Street 2', 'Address Type',
#        'City', 'Landmark', 'Facility Type', 'Status', 'Due Date',
#        'Resolution Description', 'Resolution Action Updated Date',
#        'Community Board', 'BBL', 'Borough', 'X Coordinate (State Plane)',
#        'Y Coordinate (State Plane)', 'Open Data Channel Type',
#        'Park Facility Name', 'Park Borough', 'Vehicle Type',
#        'Taxi Company Borough', 'Taxi Pick Up Location', 'Bridge Highway Name',
#        'Bridge Highway Direction', 'Road Ramp', 'Bridge Highway Segment',
#        'Latitude', 'Longitude', 'Location'],
#       dtype='object')

# %% [markdown]
# ### Let's get rid of all the unnecessary fields

# %%
df=df[['Unique Key', 'Created Date', 'Closed Date',
       'Complaint Type', 'Descriptor', 'Location Type', 'Incident Zip',
       'Incident Address', 'Street Name','Address Type',
       'City', 'Status', 'Due Date',
       'Resolution Description','Borough',
       'Latitude', 'Longitude']]
df.head()
# Out:
#    Unique Key            Created Date             Closed Date  \
# 0    45980284  04/10/2020 09:10:10 AM                     NaN
# 1    45978285  04/10/2020 12:13:02 PM                     NaN
# 2    45978263  04/10/2020 07:37:51 AM  04/10/2020 05:56:21 PM
# 3    45976274  04/10/2020 01:53:42 PM                     NaN
# 4    45980927  04/10/2020 11:20:50 AM                     NaN
#
#          Complaint Type       Descriptor         Location Type  Incident Zip  \
# 0        HEAT/HOT WATER  ENTIRE BUILDING  RESIDENTIAL BUILDING       10030.0
# 1        HEAT/HOT WATER  ENTIRE BUILDING  RESIDENTIAL BUILDING       11235.0
# 2        HEAT/HOT WATER  ENTIRE BUILDING  RESIDENTIAL BUILDING       10462.0
# 3  UNSANITARY CONDITION            PESTS  RESIDENTIAL BUILDING       10462.0
# 4        HEAT/HOT WATER  ENTIRE BUILDING  RESIDENTIAL BUILDING       10458.0
#
#             Incident Address           Street Name Address Type      City  \
# 0       138 WEST  137 STREET      WEST  137 STREET      ADDRESS  NEW YORK
# 1  3105 BRIGHTON    3 STREET  BRIGHTON    3 STREET      ADDRESS  BROOKLYN
# 2      2040 BRONXDALE AVENUE      BRONXDALE AVENUE      ADDRESS     BRONX
# 3          1435 DORIS STREET          DORIS STREET      ADDRESS     BRONX
# 4     2410 WASHINGTON AVENUE     WASHINGTON AVENUE      ADDRESS     BRONX
#
#    Status Due Date                             Resolution Description  \
# 0    Open      NaN  The following complaint conditions are still o...
# 1    Open      NaN  The following complaint conditions are still o...
# 2  Closed      NaN  The Department of Housing Preservation and Dev...
# 3    Open      NaN  The following complaint conditions are still o...
# 4    Open      NaN  The following complaint conditions are still o...
#
#      Borough   Latitude  Longitude
# 0  MANHATTAN  40.815900 -73.941112
# 1   BROOKLYN  40.576327 -73.964056
# 2      BRONX  40.850795 -73.866537
# 3      BRONX  40.835502 -73.849272
# 4      BRONX  40.858053 -73.890913

# %%
df[['Address Type']].describe()
# Out:
#        Address Type
# count       6003012
# unique            1
# top         ADDRESS
# freq        6003012

# %% [markdown]
# ### The field "Address Type" seems to have only one value. It's not useful information. We will LET IT GO

# %%
df=df.drop(columns=['Address Type'])

# %%
df_comp=df.groupby('Complaint Type')[["Unique Key"]].count()
df_comp.sort_values('Unique Key',ascending=False).head()
# Out:
#                       Unique Key
# Complaint Type
# HEAT/HOT WATER           1300488
# HEATING                   887869
# PLUMBING                  716042
# GENERAL CONSTRUCTION      500863
# UNSANITARY CONDITION      458663

# %%
df_comp=df_comp[df_comp['Unique Key']>80000].sort_values(by='Unique Key',ascending=False)
df_comp.columns=['No of complaints']
df_comp.T
# Out:
# Complaint Type    HEAT/HOT WATER  HEATING  PLUMBING  GENERAL CONSTRUCTION  \
# No of complaints         1300488   887869    716042                500863
#
# Complaint Type    UNSANITARY CONDITION  PAINT - PLASTER  PAINT/PLASTER  \
# No of complaints                458663           361257         349651
#
# Complaint Type    ELECTRIC  NONCONST  DOOR/WINDOW  WATER LEAK  GENERAL  \
# No of complaints    309214    260890       208121      196048   153816
#
# Complaint Type    FLOORING/STAIRS  APPLIANCE
# No of complaints           138862     114414

# %% [markdown]
# # ***It seems like the highest complaints are for HEAT or HOT WATER!!***

# %% [markdown]
# ### We are only going to focus on the most frequent occuring problems

# %%
print(df.shape)
df=df[df['Complaint Type'].isin(df_comp.index)]
print(df.shape)
df.head()
# Out:
# (6087779, 16)
# (5956198, 16)
#    Unique Key            Created Date             Closed Date  \
# 0    45980284  04/10/2020 09:10:10 AM                     NaN
# 1    45978285  04/10/2020 12:13:02 PM                     NaN
# 2    45978263  04/10/2020 07:37:51 AM  04/10/2020 05:56:21 PM
# 3    45976274  04/10/2020 01:53:42 PM                     NaN
# 4    45980927  04/10/2020 11:20:50 AM                     NaN
#
#          Complaint Type       Descriptor         Location Type  Incident Zip  \
# 0        HEAT/HOT WATER  ENTIRE BUILDING  RESIDENTIAL BUILDING       10030.0
# 1        HEAT/HOT WATER  ENTIRE BUILDING  RESIDENTIAL BUILDING       11235.0
# 2        HEAT/HOT WATER  ENTIRE BUILDING  RESIDENTIAL BUILDING       10462.0
# 3  UNSANITARY CONDITION            PESTS  RESIDENTIAL BUILDING       10462.0
# 4        HEAT/HOT WATER  ENTIRE BUILDING  RESIDENTIAL BUILDING       10458.0
#
#             Incident Address           Street Name      City  Status Due Date  \
# 0       138 WEST  137 STREET      WEST  137 STREET  NEW YORK    Open      NaN
# 1  3105 BRIGHTON    3 STREET  BRIGHTON    3 STREET  BROOKLYN    Open      NaN
# 2      2040 BRONXDALE AVENUE      BRONXDALE AVENUE     BRONX  Closed      NaN
# 3          1435 DORIS STREET          DORIS STREET     BRONX    Open      NaN
# 4     2410 WASHINGTON AVENUE     WASHINGTON AVENUE     BRONX    Open      NaN
#
#                               Resolution Description    Borough   Latitude  \
# 0  The following complaint conditions are still o...  MANHATTAN  40.815900
# 1  The following complaint conditions are still o...   BROOKLYN  40.576327
# 2  The Department of Housing Preservation and Dev...      BRONX  40.850795
# 3  The following complaint conditions are still o...      BRONX  40.835502
# 4  The following complaint conditions are still o...      BRONX  40.858053
#
#    Longitude
# 0 -73.941112
# 1 -73.964056
# 2 -73.866537
# 3 -73.849272
# 4 -73.890913

# %% [markdown]
# ### Which area had the largest number of complaints?

# %%
df_bor= df.groupby('Borough')[['Unique Key']].count().sort_values('Unique Key',ascending=False)
df_bor
# Out:
#                Unique Key
# Borough
# BROOKLYN          1731517
# BRONX             1621995
# MANHATTAN         1055419
# Unspecified        818832
# QUEENS             641707
# STATEN ISLAND       86728

# %% [markdown]
# ## It seems like Brooklyn has the highest number of complaints. But BRONX is also very close. There are also some unspecified entries. We will have to find what borough those zip numbers belong to.

# %%
df_pluto = pd.read_csv('/kaggle/input/nyc-pluto/pluto_20v2.csv')
df_pluto.head()
# Out:
# /opt/conda/lib/python3.6/site-packages/IPython/core/interactiveshell.py:3063: DtypeWarning: Columns (16,17,18,20,22,24,62) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)
#   borough  block  lot     cd   ct2010  cb2010  schooldist  council  zipcode  \
# 0      QN   3331   57  409.0   136.00  2001.0        28.0     29.0  11415.0
# 1      MN   1140   27  107.0   153.00  2000.0         3.0      6.0  10023.0
# 2      QN  10192   43  412.0   264.00  1004.0        28.0     27.0  11433.0
# 3      BK   1549    4  303.0   301.00  3000.0        16.0     41.0  11233.0
# 4      QN  15706   61  414.0  1008.02  1010.0        27.0     31.0  11691.0
#
#   firecomp  ...  appbbl  appdate  plutomapid version sanitdistrict  \
# 0     E298  ...     NaN      NaN           1    20v2           9.0
# 1     L035  ...     NaN      NaN           1    20v2           7.0
# 2     E275  ...     NaN      NaN           1    20v2          12.0
# 3     L176  ...     NaN      NaN           1    20v2           3.0
# 4     E328  ...     NaN      NaN           1    20v2          14.0
#
#   healthcenterdistrict firm07_flag pfirm15_flag dcpedited notes
# 0                 45.0         NaN          NaN       NaN   NaN
# 1                 15.0         NaN          NaN       NaN   NaN
# 2                 44.0         NaN          NaN       NaN   NaN
# 3                 32.0         NaN          NaN         t   NaN
# 4                 45.0         NaN          NaN       NaN   NaN
#
# [5 rows x 90 columns]

# %%
df_zip=df.groupby('Incident Zip')[['Borough']].agg(lambda x:x.value_counts().index[0])
df_zip.head()
# Out:
#                 Borough
# Incident Zip
# 10001.0       MANHATTAN
# 10002.0       MANHATTAN
# 10003.0       MANHATTAN
# 10004.0       MANHATTAN
# 10005.0       MANHATTAN

# %%
for i,j in zip(df[df['Borough']=='Unspecified'].index,df[df['Borough']=='Unspecified']['Incident Zip']):
    if np.isnan(j):
        continue
    df.at[i,'Borough']=df_zip.at[j,'Borough']
    #print(type(j))

# %%
df[df['Borough']=='Unspecified'].head()
# Out:
#         Unique Key            Created Date             Closed Date  \
# 6462      45534862  02/03/2020 04:09:47 PM  02/21/2020 09:13:21 AM
# 245677    19682256  01/25/2011 12:00:00 AM  01/30/2011 12:00:00 AM
# 245889    19023113  11/01/2010 12:00:00 AM  11/12/2010 12:00:00 AM
# 264446    43950950  10/02/2019 06:09:24 AM  10/17/2019 08:57:30 AM
# 307324    15635792  01/01/2010 12:00:00 AM  01/13/2010 12:00:00 AM
#
#        Complaint Type      Descriptor         Location Type  Incident Zip  \
# 6462         PLUMBING  BATHTUB/SHOWER  RESIDENTIAL BUILDING           NaN
# 245677        HEATING            HEAT  RESIDENTIAL BUILDING           NaN
# 245889        HEATING            HEAT  RESIDENTIAL BUILDING           NaN
# 264446       ELECTRIC    POWER OUTAGE  RESIDENTIAL BUILDING           NaN
# 307324        HEATING            HEAT  RESIDENTIAL BUILDING           NaN
#
#                         Incident Address                Street Name City  \
# 6462                    149 WESER AVENUE               WESER AVENUE  NaN
# 245677  102-23 HARACE HARDING EXPRESSWAY  HARACE HARDING EXPRESSWAY  NaN
# 245889             146-26 BURLING STREET             BURLING STREET  NaN
# 264446                 147 SCRIBNER LANE              SCRIBNER LANE  NaN
# 307324                   63-11 63 STREET                  63 STREET  NaN
#
#         Status Due Date                             Resolution Description  \
# 6462    Closed      NaN  The Department of Housing Preservation and Dev...
# 245677  Closed      NaN  The Department of Housing Preservation and Dev...
# 245889  Closed      NaN  The Department of Housing Preservation and Dev...
# 264446  Closed      NaN  The Department of Housing Preservation and Dev...
# 307324  Closed      NaN  The Department of Housing Preservation and Dev...
#
#             Borough  Latitude  Longitude
# 6462    Unspecified       NaN        NaN
# 245677  Unspecified       NaN        NaN
# 245889  Unspecified       NaN        NaN
# 264446  Unspecified       NaN        NaN
# 307324  Unspecified       NaN        NaN

# %%
df.groupby('Borough')[['Unique Key']].count().sort_values('Unique Key',ascending=False)
# Out:
#                Unique Key
# Borough
# BROOKLYN          2026221
# BRONX             1873618
# MANHATTAN         1208830
# QUEENS             745901
# STATEN ISLAND      101070
# Unspecified           558

# %% [markdown]
# ## We still have some Unspecified values. But they are because their zip wasn't given. Since their number is now less by multiple factors of ten, we will ignore the rest.

# %% [markdown]
# ### Let's see which address has the most complaints

# %%
df.groupby('Incident Address')[['Unique Key']].count().sort_values('Unique Key',ascending=False)
# Out:
#                        Unique Key
# Incident Address
# 34 ARDEN STREET             14362
# 89-21 ELMHURST AVENUE       13343
# 1025 BOYNTON AVENUE          9729
# 3810 BAILEY AVENUE           7178
# 9511 SHORE ROAD              5539
# ...                           ...
# 534 PUGSLEY AVENUE              1
# 188-22 87 DRIVE                 1
# 534 TARGEE STREET               1
# 188-20C 69 AVENUE               1
# UNKNOWN                         1
#
# [182867 rows x 1 columns]

# %%
df[df['Incident Address']=='34 ARDEN STREET'][['Incident Address','Incident Zip','Borough']].head(1)
# Out:
#     Incident Address  Incident Zip    Borough
# 472  34 ARDEN STREET       10040.0  MANHATTAN

# %% [markdown]
# ### The address where most number of complaints came from is
# # 34 ARDEN STREET, MANHATTAN 10040

# %%
df.groupby('Incident Zip')[['Unique Key']].count().sort_values('Unique Key',ascending=False).head()
# Out:
#               Unique Key
# Incident Zip
# 11226.0           215792
# 10467.0           174156
# 10458.0           169767
# 10453.0           162725
# 10468.0           148501

# %% [markdown]
# ## The zipcode where the most number of complaints came from is
# # 11226

# %%
df.groupby('Status')[['Unique Key']].count().sort_values('Unique Key',ascending=False).head()
# Out:
#          Unique Key
# Status
# Closed      5821801
# Open         134395
# Pending           2

# %%
df_pluto=df_pluto[['address','bldgarea','bldgdepth','builtfar','commfar','facilfar','lot','lotarea',
                   'lotdepth','numbldgs','numfloors','officearea','resarea','residfar','retailarea',
                   'yearbuilt','yearalter1','zipcode','ycoord','xcoord']]
df_pluto.shape
# Out:
# (859038, 20)

# %%
df_pluto['bldgage']=2020-df_pluto['yearbuilt']
df_pluto.head()
# Out:
#                    address  bldgarea  bldgdepth  builtfar  commfar  facilfar  \
# 0      84-33 ABINGDON ROAD    2372.0       40.0      0.47      0.0       2.0
# 1       107 WEST 68 STREET   22380.0       83.0      3.68      0.0       4.0
# 2            CLAUDE AVENUE       0.0        0.0      0.00      0.0       1.0
# 3            FULTON STREET       0.0        0.0      0.00      0.0       4.2
# 4  10-12 GRASSMERE TERRACE       0.0        0.0      0.00      0.0       2.0
#
#    lot  lotarea  lotdepth  numbldgs  ...  officearea  resarea  residfar  \
# 0   57   5000.0    100.00       2.0  ...         0.0   2372.0      0.75
# 1   27   6075.0    100.42       1.0  ...         0.0  22380.0      4.00
# 2   43   2628.0    136.00       0.0  ...         NaN      NaN      0.50
# 3    4   2000.0    100.00       0.0  ...         NaN      NaN      4.20
# 4   61   2771.0    102.03       0.0  ...         NaN      NaN      0.75
#
#    retailarea  yearbuilt  yearalter1  zipcode    ycoord     xcoord  bldgage
# 0         0.0     1920.0         0.0  11415.0  196855.0  1031306.0    100.0
# 1         0.0     1930.0      1989.0  10023.0  221723.0   989505.0     90.0
# 2         NaN        0.0         0.0  11433.0  191541.0  1043307.0   2020.0
# 3         NaN        0.0         0.0  11233.0  186469.0  1006800.0   2020.0
# 4         NaN        0.0         0.0  11691.0  158883.0  1051634.0   2020.0
#
# [5 rows x 21 columns]

# %%
df_comp_count=df.groupby('Incident Address')[['Incident Address']].count()

# %%
df_comp_count.columns=['count of complaints']
df_comp_count['address']=df_comp_count.index
df_comp_count.head()
# Out:
#                   count of complaints           address
# Incident Address
# .537 SHEPERD AVE                    4  .537 SHEPERD AVE
# 1 1 AVENUE                          2        1 1 AVENUE
# 1 1 PLACE                           3         1 1 PLACE
# 1 12 STREET                         1       1 12 STREET
# 1 23 STREET                         1       1 23 STREET

# %%
#df_comp_count.index=None
df_comp_count.reset_index(drop=True,inplace=True)
df_comp_count.head()
# Out:
#    count of complaints           address
# 0                    4  .537 SHEPERD AVE
# 1                    2        1 1 AVENUE
# 2                    3         1 1 PLACE
# 3                    1       1 12 STREET
# 4                    1       1 23 STREET

# %%
df_corr = pd.merge(df_comp_count,df_pluto,on='address')
df_corr.head()
# Out:
#    count of complaints        address  bldgarea  bldgdepth  builtfar  commfar  \
# 0                    3      1 1 PLACE    5332.0       50.0      2.48      0.0
# 1                    2     1 5 AVENUE  238923.0      100.0     19.91      0.0
# 2                    5     1 7 AVENUE   15075.0      110.0      0.94      0.0
# 3                   64    1 74 STREET  112140.0      294.0      3.36      0.0
# 4                    7  1 ADLER PLACE    1512.0       36.0      0.96      0.0
#
#    facilfar  lot  lotarea  lotdepth  ...  officearea   resarea  residfar  \
# 0       2.0   50   2150.0    100.00  ...         0.0    5332.0      2.00
# 1      10.0   22  12000.0    100.00  ...         0.0  227923.0     10.00
# 2       4.0    5  16050.0     96.25  ...         0.0       0.0      4.00
# 3       3.0    1  33400.0    294.00  ...         0.0  112140.0      3.00
# 4       2.0   66   1568.0     80.08  ...         0.0    1512.0      1.25
#
#    retailarea  yearbuilt  yearalter1  zipcode    ycoord     xcoord  bldgage
# 0         0.0     1900.0      1982.0  11231.0  187611.0   984123.0    120.0
# 1     11000.0     1926.0      1988.0  10003.0  205930.0   985305.0     94.0
# 2     15075.0     1900.0         0.0  11217.0  186061.0   991719.0    120.0
# 3         0.0     1938.0         0.0  11209.0  170478.0   974216.0     82.0
# 4         0.0     1920.0         0.0  11208.0  188877.0  1019618.0    100.0
#
# [5 rows x 22 columns]

# %%
print(df_comp_count.shape)
print(df_pluto.shape)
df_corr.shape
# Out:
# (182867, 2)
# (859038, 21)
# (142710, 22)

# %%
df_corr.corr()
# Out:
#                      count of complaints  bldgarea  bldgdepth  builtfar  \
# count of complaints             1.000000  0.097426   0.162229  0.089475
# bldgarea                        0.097426  1.000000   0.290120  0.457397
# bldgdepth                       0.162229  0.290120   1.000000  0.170076
# builtfar                        0.089475  0.457397   0.170076  1.000000
# commfar                        -0.021558  0.195094   0.137881  0.227412
# facilfar                        0.129655  0.212181   0.262826  0.308852
# lot                            -0.011392  0.124292  -0.025010  0.122556
# lotarea                         0.027738  0.302213   0.122172  0.011359
# lotdepth                        0.069044  0.406654   0.321090  0.024113
# numbldgs                       -0.016470  0.143215   0.004894 -0.027139
# numfloors                       0.148636  0.494651   0.300172  0.441755
# officearea                     -0.008231  0.397871   0.134987  0.125707
# resarea                         0.165390  0.623516   0.275001  0.182936
# residfar                        0.122435  0.205910   0.250923  0.325960
# retailarea                      0.004708  0.224030   0.113024  0.068506
# yearbuilt                       0.006644  0.019414   0.098898  0.030435
# yearalter1                      0.057835  0.071891   0.161832  0.148602
# zipcode                        -0.094110 -0.113277  -0.148980 -0.196368
# ycoord                          0.114882  0.060287   0.096937  0.096571
# xcoord                         -0.013338 -0.045015  -0.094440 -0.108675
# bldgage                        -0.006644 -0.019414  -0.098898 -0.030435
#
#                       commfar  facilfar       lot   lotarea  lotdepth  \
# count of complaints -0.021558  0.129655 -0.011392  0.027738  0.069044
# bldgarea             0.195094  0.212181  0.124292  0.302213  0.406654
# bldgdepth            0.137881  0.262826 -0.025010  0.122172  0.321090
# builtfar             0.227412  0.308852  0.122556  0.011359  0.024113
# commfar              1.000000  0.497404  0.125636  0.014596  0.036042
# facilfar             0.497404  1.000000  0.120924  0.012921  0.025221
# lot                  0.125636  0.120924  1.000000  0.035919 -0.005342
# lotarea              0.014596  0.012921  0.035919  1.000000  0.503267
# lotdepth             0.036042  0.025221 -0.005342  0.503267  1.000000
# numbldgs            -0.014142 -0.053082  0.057543  0.289445  0.234118
# numfloors            0.399586  0.507358  0.249468  0.082892  0.194916
# officearea           0.255903  0.141514  0.036407  0.116675  0.155099
# resarea              0.087980  0.206506  0.141548  0.268479  0.378341
# residfar             0.428192  0.854016  0.129733  0.007612  0.008634
# retailarea           0.144676  0.097823  0.058683  0.074088  0.141594
# yearbuilt           -0.046126 -0.047386 -0.016734 -0.029802 -0.009899
# yearalter1           0.152968  0.300273  0.010673  0.016345  0.029062
# zipcode             -0.256341 -0.481069 -0.057861 -0.020338 -0.026759
# ycoord               0.040970  0.300637  0.005356  0.013214  0.007452
# xcoord              -0.152642 -0.196543 -0.056790 -0.002485 -0.014669
# bldgage              0.046126  0.047386  0.016734  0.029802  0.009899
#
#                      numbldgs  ...  officearea   resarea  residfar  \
# count of complaints -0.016470  ...   -0.008231  0.165390  0.122435
# bldgarea             0.143215  ...    0.397871  0.623516  0.205910
# bldgdepth            0.004894  ...    0.134987  0.275001  0.250923
# builtfar            -0.027139  ...    0.125707  0.182936  0.325960
# commfar             -0.014142  ...    0.255903  0.087980  0.428192
# facilfar            -0.053082  ...    0.141514  0.206506  0.854016
# lot                  0.057543  ...    0.036407  0.141548  0.129733
# lotarea              0.289445  ...    0.116675  0.268479  0.007612
# lotdepth             0.234118  ...    0.155099  0.378341  0.008634
# numbldgs             1.000000  ...    0.027591  0.183762 -0.055859
# numfloors           -0.012648  ...    0.289377  0.517826  0.537269
# officearea           0.027591  ...    1.000000  0.006777  0.109857
# resarea              0.183762  ...    0.006777  1.000000  0.222498
# residfar            -0.055859  ...    0.109857  0.222498  1.000000
# retailarea           0.009603  ...    0.095596  0.073213  0.092816
# yearbuilt           -0.008103  ...    0.006847  0.016526 -0.042848
# yearalter1          -0.012335  ...    0.036458  0.065270  0.316927
# zipcode              0.028656  ...   -0.054702 -0.120422 -0.489157
# ycoord              -0.018000  ...    0.011712  0.081372  0.283762
# xcoord               0.037440  ...   -0.028124 -0.040293 -0.224094
# bldgage              0.008103  ...   -0.006847 -0.016526  0.042848
#
#                      retailarea  yearbuilt  yearalter1   zipcode    ycoord  \
# count of complaints    0.004708   0.006644    0.057835 -0.094110  0.114882
# bldgarea               0.224030   0.019414    0.071891 -0.113277  0.060287
# bldgdepth              0.113024   0.098898    0.161832 -0.148980  0.096937
# builtfar               0.068506   0.030435    0.148602 -0.196368  0.096571
# commfar                0.144676  -0.046126    0.152968 -0.256341  0.040970
# facilfar               0.097823  -0.047386    0.300273 -0.481069  0.300637
# lot                    0.058683  -0.016734    0.010673 -0.057861  0.005356
# lotarea                0.074088  -0.029802    0.016345 -0.020338  0.013214
# lotdepth               0.141594  -0.009899    0.029062 -0.026759  0.007452
# numbldgs               0.009603  -0.008103   -0.012335  0.028656 -0.018000
# numfloors              0.144647   0.096057    0.210983 -0.325152  0.163015
# officearea             0.095596   0.006847    0.036458 -0.054702  0.011712
# resarea                0.073213   0.016526    0.065270 -0.120422  0.081372
# residfar               0.092816  -0.042848    0.316927 -0.489157  0.283762
# retailarea             1.000000   0.001771    0.042029 -0.050439  0.015202
# yearbuilt              0.001771   1.000000   -0.017676  0.046924 -0.018866
# yearalter1             0.042029  -0.017676    1.000000 -0.291694  0.141543
# zipcode               -0.050439   0.046924   -0.291694  1.000000 -0.519612
# ycoord                 0.015202  -0.018866    0.141543 -0.519612  1.000000
# xcoord                -0.025648   0.044679   -0.125876  0.418741  0.345170
# bldgage               -0.001771  -1.000000    0.017676 -0.046924  0.018866
#
#                        xcoord   bldgage
# count of complaints -0.013338 -0.006644
# bldgarea            -0.045015 -0.019414
# bldgdepth           -0.094440 -0.098898
# builtfar            -0.108675 -0.030435
# commfar             -0.152642  0.046126
# facilfar            -0.196543  0.047386
# lot                 -0.056790  0.016734
# lotarea             -0.002485  0.029802
# lotdepth            -0.014669  0.009899
# numbldgs             0.037440  0.008103
# numfloors           -0.155373 -0.096057
# officearea          -0.028124 -0.006847
# resarea             -0.040293 -0.016526
# residfar            -0.224094  0.042848
# retailarea          -0.025648 -0.001771
# yearbuilt            0.044679 -1.000000
# yearalter1          -0.125876  0.017676
# zipcode              0.418741 -0.046924
# ycoord               0.345170  0.018866
# xcoord               1.000000 -0.044679
# bldgage             -0.044679  1.000000
#
# [21 rows x 21 columns]
